# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
a=np.arange(1,7)
b=np.arange(11,17)

# %%
y=a*a

# %%
plt.plot(a,y,'g',linestyle='--',linewidth='3')
plt.xlabel('x axis')
# Out:
# Text(0.5, 0, 'x axis')

# %%
plt.scatter(a,b,c='b')
plt.xlabel('Xaxis')
plt.ylabel('Yaxis')
plt.title('2D graph')
# Out:
# Text(0.5, 1.0, '2D graph')

# %%
#creating subplot
plt.subplot(1,2,1)
plt.plot(a,b,linestyle='--',c='r')
plt.subplot(1,2,2)
plt.plot(a,y)
plt.title('Subplot')
# Out:
# Text(0.5, 1.0, 'Subplot')

# %%
np.pi
# Out:
# 3.141592653589793

# %%
x=np.arange(0,4*np.pi)
y=np.sin(x)
plt.plot(x,y)

# %%
x=np.arange(0,4*np.pi,0.1)
y=np.sin(x)
plt.subplot(2,1,1)
plt.plot(x,y,c='g')

plt.subplot(2,1,2)
z=np.tan(x)
plt.plot(x,z,c='r')

# %%
#barplot

# %%
x=[2,3,5]
y=[1,2,1]

x2=[4,11,12]
y2=[3,4,3]
plt.bar(x,y,width=0.5,color='g')
plt.bar(x2,y2,color='b')
plt.show()

# %%
#histogram
import numpy as np
import matplotlib.pyplot as plt
a=np.array([23,24,23,25,26,23,24,27,28,28,29,29])
plt.hist(a,color='black',bins=11)
plt.title('histogram')
plt.show()

# %%
#box plot

# %%
for std in range(1,4):
    data=[np.random.normal(0,std,100)] 
    plt.boxplot(data,vert=False,patch_artist=True)

# %%
plt.boxplot(data,vert=True,patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25b12156990>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x25b122b5150>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x25b1224ce90>],
#  'medians': [<matplotlib.lines.Line2D at 0x25b122b61d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x25b122b6950>],
#  'means': []}

# %%
#pie chart

# %%
x=[20,40,60,30]
plt.pie(x,labels=['A','B','C','D'],radius=1.2,explode=[0.09,0.07,0,0],autopct='%1.1f%%')
plt.show()

# %%
#3d plot

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

# %%
import matplotlib.pyplot as plt
import numpy as np


fig = plt.figure()
ax = fig.add_subplot(projection='3d')

colors = ['r', 'black', 'b', 'green']
yticks = [3, 2, 1, 0]
for c, k in zip(colors, yticks):
    # Generate the random data for the y=k 'layer'.
    xs = np.arange(20)
    ys = np.random.rand(20)

    # You can provide either a single color or an array with the same length as
    # xs and ys. To demonstrate this, we color the first bar of each set cyan.
    cs = [c] * len(xs)
    cs[0] = 'c'

    # Plot the bar graph given by xs and ys on the plane y=k with 80% opacity.
    ax.bar(xs, ys, zs=k, zdir='y', color=cs, alpha=0.8)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# On the y-axis let's only label the discrete values that we have data for.
ax.set_yticks(yticks)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# Create sample data
n = 100
x = np.random.rand(n)
y = np.random.rand(n)
z = np.random.rand(n)

# Create a 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Create the scatter plot
ax.scatter3D(x, y, z, c=z, cmap='viridis', s=50)

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Scatter Plot')

plt.show()

# %%
#subplot

# %%
import matplotlib.pyplot as plt

# Sample data for subplots
x = [1, 2, 3, 4, 5]
y1 = [2, 4, 6, 8, 10]
y2 = [5, 3, 7, 2, 8]

# Create a figure with two subplots (1 row, 2 columns)
fig, axs = plt.subplots(1, 2, figsize=(10, 4))

# First subplot
axs[0].plot(x, y1, label='Line 1', color='blue')

# Second subplot
axs[1].plot(x, y2, label='Line 2', color='red')


# Display the subplots
plt.show()
